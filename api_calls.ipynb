# %% [markdown]
# ## Aquiring Data

# %%
import pandas as pd
import numpy as np

import json
import requests
from requests.auth import HTTPBasicAuth
from pprint import pprint

from config import basic_auth_username, basic_auth_password
from config import basic_auth_username_read_only, basic_auth_password_read_only

# %%
def search_current_user():
    """ returns current (my) user metadata """
    response =requests.get('https://api.ravelry.com/current_user.json', auth=HTTPBasicAuth(basic_auth_username, basic_auth_password))
    if response.status_code != 200:
        print("Something's not quite right - please take a look, status_code = {}".format(response.status_code))
    else:
        return response.json()

# %%
search_current_user()
# Out:
# {'user': {'id': 264731,
#   'username': 'upsidedown',
#   'tiny_photo_url': 'https://avatars-d.ravelrycache.com/upsidedown/122038936/IMG_2763_tiny.JPG',
#   'small_photo_url': 'https://avatars-d.ravelrycache.com/upsidedown/122038936/IMG_2763_small.JPG',
#   'photo_url': 'https://avatars-d.ravelrycache.com/upsidedown/122038936/IMG_2763_large.JPG',
#   'large_photo_url': 'https://avatars-d.ravelrycache.com/upsidedown/122038936/IMG_2763_xlarge.JPG'}}

# %%
params = params

# %%
def search(params, end_point):
        """ gets data from ravelry api with given end point (string) and parameters (dictionary)
        outlined in the api documentation """
        base_url = 'https://api.ravelry.com/'
        params = params
        response =requests.get('https://api.ravelry.com/'+end_point, params=params,auth=HTTPBasicAuth(basic_auth_username, basic_auth_password))
        if response.status_code != 200:
            print("Something's not quite right - please take a look, status_code = {}".format(response.status_code))
        return(response.json())

# %%
# get pattern categories list
# start with one category
# then iterate through grab patterns for each if <100k
# combine into one monster dataframe

# write a script to interate through all id's grab info, write to csv... append with all info

# %%
end_point = 'patterns/search.json'
params = {'query' : {'craft':'knitting'}}# 'year published': '2020'
# params = {'query' : {'craft':'knitting', 'sort by': 'best match'}, 'limit':500, "page": 1,"page_size": 100}
response =requests.get('https://api.ravelry.com/'+end_point, params=params, auth=HTTPBasicAuth(basic_auth_username, basic_auth_password))
# response =requests.get('https://api.ravelry.com/search.json?patterns/knitting', auth=HTTPBasicAuth(basic_auth_username, basic_auth_password))

# %%
results = response.json()
results
pattern_id = []
pattern_name =[]
for i in range(len(results['patterns'])):
    pattern_id.append(results['patterns'][i]['id'])
    pattern_name.append(results['patterns'][i]['name'])
len(pattern_id)
results['patterns'][1]
# pattern_name[0:15]
# Out:
# {'free': True,
#  'id': 464516,
#  'name': 'Craft bag',
#  'permalink': 'craft-bag',
#  'personal_attributes': None,
#  'first_photo': {'id': 37401464,
#   'sort_order': 1,
#   'x_offset': 0,
#   'y_offset': -43,
#   'square_url': 'https://images4-f.ravelrycache.com/uploads/lgcmag/208877032/LGC58-050.eip.p_square.jpg',
#   'medium_url': 'https://images4-f.ravelrycache.com/uploads/lgcmag/208877032/LGC58-050.eip.p_medium.jpg',
#   'thumbnail_url': 'https://images4-f.ravelrycache.com/uploads/lgcmag/208877032/LGC58-050.eip.p_thumbnail.jpg',
#   'small_url': 'https://images4-f.ravelrycache.com/uploads/lgcmag/208877032/LGC58-050.eip.p_small_best_fit.jpg',
#   'medium2_url': 'https://images4-g.ravelrycache.com/uploads/lgcmag/208877032/LGC58-050.eip.p_medium2.jpg',
#   'small2_url': 'https://images4-f.ravelrycache.com/uploads/lgcmag/208877032/LGC58-050.eip.p_small2.jpg',
#   'caption': None,
#   'caption_html': None,
#   'copyright_holder': 'letsgetcrafting'},
#  'designer': {'crochet_pattern_count': 0,
#   'favorites_count': 4,
#   'id': 60311,
#   'knitting_pattern_count': 25,
#   'name': 'Wendy Mould',
#   'patterns_count': 25,
#   'permalink': 'wendy-mould',
#   'users': []},
#  'pattern_author': {'crochet_pattern_count': 0,
#   'favorites_count': 4,
#   'id': 60311,
#   'knitting_pattern_count': 25,
#   'name': 'Wendy Mould',
#   'patterns_count': 25,
#   'permalink': 'wendy-mould',
#   'users': []},
#  'pattern_sources': [{'amazon_rating': None,
#    'amazon_reviews': None,
#    'amazon_sales_rank': None,
#    'amazon_updated_at': None,
#    'amazon_url': None,
#    'approved_patterns_count': 2,
#    'asin': '',
#    'author': '',
#    'author_pattern_author_id': None,
#    'author_surname': '',
#    'book_binding': None,
#    'completed': False,
#    'created_at': '2014/01/22 06:13:00 -0500',
#    'created_by_user_id': 496946,
#    'designer_pending_patterns_count': 0,
#    'designer_users_count': 0,
#    'editorships_count': 0,
#    'favorites_count': 2,
#    'first_photo_id': 37401274,
#    'flaggings_count': 0,
#    'fulfilled_by_ravelry': False,
#    'has_photo': True,
#    'id': 159411,
#    'isbn_13': None,
#    'issue': '58',
#    'keywords': '',
#    'label': None,
#    'large_image_url': None,
#    'last_pattern_edit': '2020/11/08 07:41:00 -0500',
#    'link_id': 196295,
#    'list_price': None,
#    'lock_version': 9,
#    'medium_image_url': None,
#    'name': "Let's Get Crafting Knitting & Crochet #58",
#    'out_of_print': False,
#    'pattern_source_type_id': 2,
#    'patterns_count': 24,
#    'pending_patterns_count': 22,
#    'periodical': True,
#    'permalink': 'lets-get-crafting-knitting--crochet-58',
#    'photos_permitted': False,
#    'popularity': 0.0,
#    'popularity_rank': 2147483647,
#    'price': None,
#    'publication_date': '2014/01/01',
#    'publication_date_set': 1,
#    'publication_day_set': 0,
#    'publication_sort_order': 1388534400,
#    'publication_year': 2014,
#    'publisher_id': None,
#    'shelf_image_path': 'http://images4.ravelry.com/uploads/lgcmag/208875645/0001408857_shelved.jpg',
#    'shelf_image_size': '105x150',
#    'small_image_url': 'http://images4.ravelry.com/uploads/lgcmag/208875645/0001408857_square.jpg',
#    'source_group_id': 1904,
#    'stickies_count': 0,
#    'store_id': None,
#    'updated_at': '2017/12/14 13:49:24 -0500',
#    'url': 'http://www.letsgetcrafting.com',
#    'work_id': None,
#    'notes': ''}]}

# %%
# create pandas df
# save to csv

# %%
import requests

result = requests.get(
#     "patterns/search"
    'https://api.ravelry.com/patterns.json',
    data={
        "query": "",
        "page": 1,
        "page_size": 100
    },
    auth=HTTPBasicAuth(basic_auth_username, basic_auth_password)
)

# %%
pprint(result)
# Out:
# <Response [400]>

# %%
# params = {'ids':'600 601', 'craft': {'id': 2,
#                                 'name': 'Knitting',
#                                 'permalink': 'knitting'}}
# end_point = 'patterns.json' 
end_point = 'search.json'
params = {'query':'Knitting', 'types':}
# params = {'craft': {'id': 2,'name': 'Knitting','permalink': 'knitting'}}
pattern = search(params, end_point)
# Out:
# Something's not quite right - please take a look, status_code = 400

# %%
pprint(pattern)

id_ = []
name = []
favorites_count = []
projects_count = []
difficulty_average = []
difficulty_count = []
rating_average = []
rating_count = []

# parse json response 
for i in pattern['patterns']:#['600', '601']:
    id_.append(pattern['patterns'][i]['id'])
    name.append(pattern['patterns'][i]['name'])
    favorites_count.append(pattern['patterns'][i]['favorites_count'])
    projects_count.append(pattern['patterns'][i]['projects_count'])
    difficulty_average.append(pattern['patterns'][i]['difficulty_average'])
    difficulty_count.append(pattern['patterns'][i]['difficulty_count'])
    rating_average.append(pattern['patterns'][i]['rating_average'])
    rating_count.append(pattern['patterns'][i]['rating_count'])

print(name)
# 'craft': {'id': 2, 'name': 'Knitting', 'permalink': 'knitting'},

# created_at = pattern['patterns']['600']['created_at']
# pattern['patterns']['600']['difficulty_average']
# pattern['patterns']['600']['difficulty_count'] # get weighted difficulty
# pattern['patterns']['600']['downloadable']
# pattern['patterns']['600']['favorites_count']
# pattern['patterns']['600']['free'][]
# pattern['patterns']['600']['gauge']
# pattern['patterns']['600']['gauge_divisor']
# pattern['patterns']['600']['gauge_pattern']
# pattern['patterns']['600']['generally_available']
# pattern['patterns']['600'][]
# pattern['patterns']['600'][]
# pattern['patterns']['600'][]
# pattern['patterns']['600']['photos']['image_url']
# Out:
# {'patterns': {'600': {'comments_count': 1,
#                       'craft': {'id': 2,
#                                 'name': 'Knitting',
#                                 'permalink': 'knitting'},
#                       'created_at': '2007/04/05 19:23:43 -0400',
#                       'currency': 'USD',
#                       'currency_symbol': '$',
#                       'difficulty_average': 3.888888888888889,
#                       'difficulty_count': 27,
#                       'download_location': None,
#                       'downloadable': False,
#                       'favorites_count': 231,
#                       'free': False,
#                       'gauge': 25.0,
#                       'gauge_description': '25 stitches and 34 rows = 4 inches '
#                                            'in Stockinette stitch',
#                       'gauge_divisor': 4,
#                       'gauge_pattern': 'Stockinette stitch',
#                       'generally_available': '2007/04/05 19:23:43 -0400',
#                       'id': 600,
#                       'name': 'Argyle Cardigan',
#                       'notes': 'A cute baby cardigan with ribbed edging, '
#                                'button enclosure, and argyle detailing at the '
#                                'bottom of the sweater.<br />\r\n'
#                                '<br />\r\n'
#                                'Additional supplies: Small amounts of white '
#                                'and Indigo yarn, 6 or 7 buttons.',
#                       'notes_html': '\n'
#                                     '<p>A cute baby cardigan with ribbed '
#                                     'edging, button enclosure, and argyle '
#                                     'detailing at the bottom of the '
#                                     'sweater.<br /> <br /><br /> <br '
#                                     '/>Additional supplies: Small amounts of '
#                                     'white and Indigo yarn, 6 or 7 '
#                                     'buttons.</p>\n',
#                       'packs': [{'color_family_id': None,
#                                  'colorway': None,
#                                  'dye_lot': None,
#                                  'grams_per_skein': 50,
#                                  'id': 12632,
#                                  'meters_per_skein': 125.3,
#                                  'ounces_per_skein': 1.76,
#                                  'personal_name': '',
#                                  'prefer_metric_length': False,
#                                  'prefer_metric_weight': True,
#                                  'primary_pack_id': None,
#                                  'project_id': None,
#                                  'quantity_description': None,
#                                  'shop_id': None,
#                                  'shop_name': None,
#                                  'skeins': None,
#                                  'stash_id': None,
#                                  'thread_size': None,
#                                  'total_grams': None,
#                                  'total_meters': None,
#                                  'total_ounces': None,
#                                  'total_yards': None,
#                                  'yards_per_skein': 137.0,
#                                  'yarn': {'id': 3217,
#                                           'name': 'Baby Cashmerino',
#                                           'permalink': 'debbie-bliss-baby-cashmerino',
#                                           'yarn_company_id': 2,
#                                           'yarn_company_name': 'Debbie Bliss'},
#                                  'yarn_id': 3217,
#                                  'yarn_name': 'Debbie Bliss Baby Cashmerino',
#                                  'yarn_weight': {'crochet_gauge': None,
#                                                  'id': 10,
#                                                  'knit_gauge': '24-26',
#                                                  'max_gauge': None,
#                                                  'min_gauge': None,
#                                                  'name': 'Sport',
#                                                  'ply': '5',
#                                                  'wpi': '12'}}],
#                       'pattern_attributes': [{'id': 3, 'permalink': 'unisex'},
#                                              {'id': 4, 'permalink': 'baby'},
#                                              {'id': 7, 'permalink': 'toddler'},
#                                              {'id': 64, 'permalink': 'ribbed'},
#                                              {'id': 86, 'permalink': 'seamed'},
#                                              {'id': 117,
#                                               'permalink': 'long-sleeve'},
#                                              {'id': 181,
#                                               'permalink': 'stranded'},
#                                              {'id': 190,
#                                               'permalink': 'buttonholes'},
#                                              {'id': 265, 'permalink': 'chart'},
#                                              {'id': 267,
#                                               'permalink': 'written-pattern'},
#                                              {'id': 285,
#                                               'permalink': 'worked-flat'}],
#                       'pattern_author': {'crochet_pattern_count': 22,
#                                          'favorites_count': 3207,
#                                          'id': 16,
#                                          'knitting_pattern_count': 2305,
#                                          'name': 'Debbie Bliss',
#                                          'notes': 'Debbie Bliss has her own '
#                                                   'yarn line made up of '
#                                                   'beautiful classics in her '
#                                                   'signature palette. She is '
#                                                   'also the most published '
#                                                   'knitwear designer, with '
#                                                   'over 35 books, 20 booklets '
#                                                   'and her own magazine. She '
#                                                   'was also recently awarded '
#                                                   "with an MBE in the Queen's "
#                                                   '2015 Birthday Honours List '
#                                                   'for her services to hand '
#                                                   'knitting and the craft '
#                                                   'industry.',
#                                          'notes_html': '\n'
#                                                        '<p>Debbie Bliss has '
#                                                        'her own yarn line made '
#                                                        'up of beautiful '
#                                                        'classics in her '
#                                                        'signature palette. She '
#                                                        'is also the most '
#                                                        'published knitwear '
#                                                        'designer, with over 35 '
#                                                        'books, 20 booklets and '
#                                                        'her own magazine. She '
#                                                        'was also recently '
#                                                        'awarded with an MBE in '
#                                                        'the Queen’s 2015 '
#                                                        'Birthday Honours List '
#                                                        'for her services to '
#                                                        'hand knitting and the '
#                                                        'craft industry.</p>\n',
#                                          'patterns_count': 2327,
#                                          'permalink': 'debbie-bliss',
#                                          'users': [{'about_me': '',
#                                                     'about_me_html': None,
#                                                     'fave_colors': '',
#                                                     'fave_curse': '',
#                                                     'first_name': 'Debbie',
#                                                     'id': 755817,
#                                                     'large_photo_url': 'https://avatars-d.ravelrycache.com/DebbieBliss/376375163/debbie_web_headshot__xlarge.jpg',
#                                                     'location': 'London, '
#                                                                 'Greater '
#                                                                 'London, '
#                                                                 'United '
#                                                                 'Kingdom',
#                                                     'pattern_author': {'favorites_count': 3207,
#                                                                        'id': 16,
#                                                                        'name': 'Debbie '
#                                                                                'Bliss',
#                                                                        'patterns_count': 2327,
#                                                                        'permalink': 'debbie-bliss'},
#                                                     'photo_url': 'https://avatars-d.ravelrycache.com/DebbieBliss/376375163/debbie_web_headshot__large.jpg',
#                                                     'small_photo_url': 'https://avatars-d.ravelrycache.com/DebbieBliss/376375163/debbie_web_headshot__small.jpg',
#                                                     'tiny_photo_url': 'https://avatars-d.ravelrycache.com/DebbieBliss/376375163/debbie_web_headshot__tiny.jpg',
#                                                     'user_sites': [{'id': 263451,
#                                                                     'social_site': {'active': True,
#                                                                                     'favicon_url': 'http:///images/assets/external/supertinyicons/facebook.svg',
#                                                                                     'id': 8,
#                                                                                     'name': 'Facebook'},
#                                                                     'url': 'http://www.facebook.com/debbieblissonline',
#                                                                     'username': 'debbieblissonline'},
#                                                                    {'id': 263452,
#                                                                     'social_site': {'active': True,
#                                                                                     'favicon_url': 'http:///images/assets/external/supertinyicons/twitter.svg',
#                                                                                     'id': 9,
#                                                                                     'name': 'Twitter'},
#                                                                     'url': 'http://twitter.com/debbieblissnews',
#                                                                     'username': 'debbieblissnews'},
#                                                                    {'id': 263453,
#                                                                     'social_site': {'active': True,
#                                                                                     'favicon_url': 'http:///images/assets/external/supertinyicons/instagram.svg',
#                                                                                     'id': 28,
#                                                                                     'name': 'Instagram'},
#                                                                     'url': 'http://instagram.com/debbieblissknits',
#                                                                     'username': 'debbieblissknits'}],
#                                                     'username': 'DebbieBliss'}]},
#                       'pattern_categories': [{'id': 304,
#                                               'name': 'Cardigan',
#                                               'parent': {'id': 319,
#                                                          'name': 'Sweater',
#                                                          'parent': {'id': 302,
#                                                                     'name': 'Clothing',
#                                                                     'parent': {'id': 301,
#                                                                                'name': 'Categories',
#                                                                                'permalink': 'categories'},
#                                                                     'permalink': 'clothing'},
#                                                          'permalink': 'sweater'},
#                                               'permalink': 'cardigan'}],
#                       'pattern_needle_sizes': [{'crochet': False,
#                                                 'hook': 'D',
#                                                 'id': 3,
#                                                 'knitting': True,
#                                                 'metric': 3.25,
#                                                 'name': 'US 3  - 3.25 mm',
#                                                 'pretty_metric': '3.25',
#                                                 'us': '3 ',
#                                                 'us_steel': '0'},
#                                                {'crochet': False,
#                                                 'hook': None,
#                                                 'id': 20,
#                                                 'knitting': True,
#                                                 'metric': 3.0,
#                                                 'name': 'US 2½ - 3.0 mm',
#                                                 'pretty_metric': '3',
#                                                 'us': '2½',
#                                                 'us_steel': None}],
#                       'pattern_type': {'clothing': True,
#                                        'id': 5,
#                                        'name': 'Baby',
#                                        'permalink': 'baby'},
#                       'pdf_in_library': False,
#                       'pdf_url': '',
#                       'permalink': 'argyle-cardigan',
#                       'personal_attributes': {'bookmark_id': None,
#                                               'favorited': False,
#                                               'in_library': False,
#                                               'queued': False},
#                       'photos': [{'caption': None,
#                                   'caption_html': None,
#                                   'copyright_holder': None,
#                                   'flickr_url': 'http://www.flickr.com/photos/57409166@N00/119324017',
#                                   'id': 657899,
#                                   'medium2_url': 'https://images4-f.ravelrycache.com/uploads/annypurls/564079538/119324017_f15d25e534_z_medium2.jpg',
#                                   'medium_url': 'https://images4-f.ravelrycache.com/uploads/annypurls/564079538/119324017_f15d25e534_z_medium.jpg',
#                                   'shelved_url': 'https://images4-f.ravelrycache.com/uploads/annypurls/564079538/119324017_f15d25e534_z_shelved.jpg',
#                                   'small2_url': 'https://images4-f.ravelrycache.com/uploads/annypurls/564079538/119324017_f15d25e534_z_small2.jpg',
#                                   'small_url': 'https://images4-f.ravelrycache.com/uploads/annypurls/564079538/119324017_f15d25e534_z_small.jpg',
#                                   'sort_order': 1,
#                                   'square_url': 'https://images4-f.ravelrycache.com/uploads/annypurls/564079538/119324017_f15d25e534_z_square.jpg',
#                                   'thumbnail_url': 'https://images4-g.ravelrycache.com/uploads/annypurls/564079538/119324017_f15d25e534_z_thumbnail.jpg',
#                                   'x_offset': -63,
#                                   'y_offset': 0},
#                                  {'caption': None,
#                                   'caption_html': None,
#                                   'copyright_holder': None,
#                                   'flickr_url': 'http://www.flickr.com/photos/26033532@N02/2936298096',
#                                   'id': 17328748,
#                                   'medium2_url': 'https://images4-g.ravelrycache.com/flickr/2/9/3/2936298096/2936298096.jpg',
#                                   'medium_url': 'https://images4-g.ravelrycache.com/flickr/2/9/3/2936298096/2936298096.jpg',
#                                   'shelved_url': None,
#                                   'small2_url': 'https://images4-g.ravelrycache.com/flickr/2/9/3/2936298096/2936298096_n.jpg',
#                                   'small_url': 'https://images4-g.ravelrycache.com/flickr/2/9/3/2936298096/2936298096_m.jpg',
#                                   'sort_order': 2,
#                                   'square_url': 'https://images4-g.ravelrycache.com/flickr/2/9/3/2936298096/2936298096_s.jpg',
#                                   'thumbnail_url': 'https://images4-g.ravelrycache.com/flickr/2/9/3/2936298096/2936298096_t.jpg',
#                                   'x_offset': -31,
#                                   'y_offset': -12},
#                                  {'caption': None,
#                                   'caption_html': None,
#                                   'copyright_holder': None,
#                                   'flickr_url': 'http://www.flickr.com/photos/48527722@N00/447698728',
#                                   'id': 24370,
#                                   'medium2_url': 'https://images4-f.ravelrycache.com/uploads/elinor/561367483/447698728_ebe3cf7fdf_z_medium2.jpg',
#                                   'medium_url': 'https://images4-g.ravelrycache.com/uploads/elinor/561367483/447698728_ebe3cf7fdf_z_medium.jpg',
#                                   'shelved_url': 'https://images4-g.ravelrycache.com/uploads/elinor/561367483/447698728_ebe3cf7fdf_z_shelved.jpg',
#                                   'small2_url': 'https://images4-g.ravelrycache.com/uploads/elinor/561367483/447698728_ebe3cf7fdf_z_small2.jpg',
#                                   'small_url': 'https://images4-g.ravelrycache.com/uploads/elinor/561367483/447698728_ebe3cf7fdf_z_small.jpg',
#                                   'sort_order': 3,
#                                   'square_url': 'https://images4-g.ravelrycache.com/uploads/elinor/561367483/447698728_ebe3cf7fdf_z_square.jpg',
#                                   'thumbnail_url': 'https://images4-g.ravelrycache.com/uploads/elinor/561367483/447698728_ebe3cf7fdf_z_thumbnail.jpg',
#                                   'x_offset': -68,
#                                   'y_offset': 1}],
#                       'price': None,
#                       'printings': [{'pattern_source': {'amazon_rating': None,
#                                                         'amazon_url': 'https://www.amazon.com/Special-Knits-Gorgeous-Handknits-Toddlers/dp/157076302X?SubscriptionId=AKIAIVR5RCD3ZTXIG7RA&tag=ravelry-20&linkCode=xm2&camp=2025&creative=165953&creativeASIN=157076302X',
#                                                         'author': 'Debbie '
#                                                                   'Bliss',
#                                                         'id': 295,
#                                                         'list_price': '$26.95',
#                                                         'name': 'Special '
#                                                                 'Knits: 22 '
#                                                                 'Gorgeous '
#                                                                 'Handknits for '
#                                                                 'Babies and '
#                                                                 'Toddlers',
#                                                         'out_of_print': False,
#                                                         'patterns_count': 22,
#                                                         'permalink': 'special-knits-22-gorgeous-handknits-for-babies-and-toddlers',
#                                                         'price': None,
#                                                         'shelf_image_path': 'http://images4.ravelry.com/uploads/nobody/94720/51p_2bejp5wll_shelved.jpg',
#                                                         'url': ''},
#                                      'primary_source': True}],
#                       'product_id': None,
#                       'projects_count': 79,
#                       'published': None,
#                       'queued_projects_count': 34,
#                       'rating_average': 4.076923076923077,
#                       'rating_count': 26,
#                       'ravelry_download': False,
#                       'row_gauge': 34.0,
#                       'sizes_available': '0-3 months (3-6 mo., 6-9 mo., 9-12 '
#                                          'mo., 12-24 mo.)',
#                       'updated_at': '2018/11/07 08:55:26 -0500',
#                       'url': '',
#                       'volumes_in_library': [],
#                       'yardage': 548,
#                       'yardage_description': '548 - 822 yards',
#                       'yardage_max': 822,
#                       'yarn_weight': {'crochet_gauge': None,
#                                       'id': 10,
#                                       'knit_gauge': '24-26',
#                                       'max_gauge': None,
#                                       'min_gauge': None,
#                                       'name': 'Sport',
#                                       'ply': '5',
#                                       'wpi': '12'},
#                       'yarn_weight_description': 'Sport (12 wpi)'},
#               '601': {'comments_count': 0,
#                       'craft': {'id': 2,
#                                 'name': 'Knitting',
#                                 'permalink': 'knitting'},
#                       'created_at': '2007/04/05 19:32:19 -0400',
#                       'currency': 'USD',
#                       'currency_symbol': '$',
#                       'difficulty_average': 0,
#                       'difficulty_count': None,
#                       'download_location': None,
#                       'downloadable': False,
#                       'favorites_count': 8,
#                       'free': False,
#                       'gauge': 22.0,
#                       'gauge_description': '22 stitches and 29 rows = 4 inches '
#                                            'in stocking stitch (jersey) on 5mm '
#                                            'needles',
#                       'gauge_divisor': 4,
#                       'gauge_pattern': 'stocking stitch (jersey) on 5mm '
#                                        'needles',
#                       'generally_available': '2005/03/01 00:00:00 -0500',
#                       'id': 601,
#                       'name': '08 - Débardeur #426-T4-370',
#                       'notes': 'Sizes: 3 (6, 12, 18, 24) mois\r\n'
#                                'Yarn Needed: 2 (2, 3, 3, 4) balls\r\n'
#                                'Also Needed: 1 bouton 14mm',
#                       'notes_html': '\n'
#                                     '<p>Sizes: 3 (6, 12, 18, 24) mois <br '
#                                     '/>Yarn Needed: 2 (2, 3, 3, 4) balls <br '
#                                     '/>Also Needed: 1 bouton 14mm</p>\n',
#                       'packs': [{'color_family_id': None,
#                                  'colorway': None,
#                                  'dye_lot': None,
#                                  'grams_per_skein': None,
#                                  'id': 17447053,
#                                  'meters_per_skein': None,
#                                  'ounces_per_skein': None,
#                                  'personal_name': None,
#                                  'prefer_metric_length': False,
#                                  'prefer_metric_weight': True,
#                                  'primary_pack_id': None,
#                                  'project_id': None,
#                                  'quantity_description': None,
#                                  'shop_id': None,
#                                  'shop_name': None,
#                                  'skeins': None,
#                                  'stash_id': None,
#                                  'thread_size': None,
#                                  'total_grams': None,
#                                  'total_meters': None,
#                                  'total_ounces': None,
#                                  'total_yards': None,
#                                  'yards_per_skein': None,
#                                  'yarn': {'id': 3508,
#                                           'name': 'Rivage',
#                                           'permalink': 'phildar-rivage',
#                                           'yarn_company_id': 221,
#                                           'yarn_company_name': 'Phildar'},
#                                  'yarn_id': 3508,
#                                  'yarn_name': 'Phildar Rivage',
#                                  'yarn_weight': {'crochet_gauge': '',
#                                                  'id': 1,
#                                                  'knit_gauge': '18',
#                                                  'max_gauge': None,
#                                                  'min_gauge': None,
#                                                  'name': 'Aran',
#                                                  'ply': '10',
#                                                  'wpi': '8'}}],
#                       'pattern_attributes': [{'id': 2, 'permalink': 'female'},
#                                              {'id': 4, 'permalink': 'baby'},
#                                              {'id': 7, 'permalink': 'toddler'},
#                                              {'id': 61, 'permalink': 'eyelets'},
#                                              {'id': 70,
#                                               'permalink': 'textured'},
#                                              {'id': 97,
#                                               'permalink': 'crew-neck'},
#                                              {'id': 121,
#                                               'permalink': 'sleeveless'},
#                                              {'id': 136,
#                                               'permalink': 'buttoned'},
#                                              {'id': 139,
#                                               'permalink': 'backfastening'},
#                                              {'id': 190,
#                                               'permalink': 'buttonholes'},
#                                              {'id': 62, 'permalink': 'lace'},
#                                              {'id': 86, 'permalink': 'seamed'},
#                                              {'id': 267,
#                                               'permalink': 'written-pattern'},
#                                              {'id': 285,
#                                               'permalink': 'worked-flat'}],
#                       'pattern_author': {'crochet_pattern_count': 237,
#                                          'favorites_count': 1274,
#                                          'id': 202,
#                                          'knitting_pattern_count': 3551,
#                                          'name': 'Phildar Design Team',
#                                          'notes': '',
#                                          'notes_html': None,
#                                          'patterns_count': 3788,
#                                          'permalink': 'phildar-design-team',
#                                          'users': []},
#                       'pattern_categories': [{'id': 308,
#                                               'name': 'Sleeveless Top',
#                                               'parent': {'id': 912,
#                                                          'name': 'Tops',
#                                                          'parent': {'id': 302,
#                                                                     'name': 'Clothing',
#                                                                     'parent': {'id': 301,
#                                                                                'name': 'Categories',
#                                                                                'permalink': 'categories'},
#                                                                     'permalink': 'clothing'},
#                                                          'permalink': 'tops'},
#                                               'permalink': 'sleeveless-top'}],
#                       'pattern_needle_sizes': [{'crochet': False,
#                                                 'hook': None,
#                                                 'id': 7,
#                                                 'knitting': True,
#                                                 'metric': 4.5,
#                                                 'name': 'US 7  - 4.5 mm',
#                                                 'pretty_metric': '4.5',
#                                                 'us': '7 ',
#                                                 'us_steel': None},
#                                                {'crochet': False,
#                                                 'hook': 'H',
#                                                 'id': 8,
#                                                 'knitting': True,
#                                                 'metric': 5.0,
#                                                 'name': 'US 8  - 5.0 mm',
#                                                 'pretty_metric': '5',
#                                                 'us': '8 ',
#                                                 'us_steel': None}],
#                       'pattern_type': {'clothing': True,
#                                        'id': 5,
#                                        'name': 'Baby',
#                                        'permalink': 'baby'},
#                       'pdf_in_library': False,
#                       'pdf_url': '',
#                       'permalink': '08---debardeur-426-t4-370',
#                       'personal_attributes': {'bookmark_id': None,
#                                               'favorited': False,
#                                               'in_library': False,
#                                               'queued': False},
#                       'photos': [{'caption': None,
#                                   'caption_html': None,
#                                   'copyright_holder': None,
#                                   'flickr_url': 'http://www.flickr.com/photos/48527722@N00/447701457',
#                                   'id': 24371,
#                                   'medium2_url': 'https://images4-f.ravelrycache.com/uploads/elinor/561363442/447701457_f2ed2ec151_z_medium2.jpg',
#                                   'medium_url': 'https://images4-f.ravelrycache.com/uploads/elinor/561363442/447701457_f2ed2ec151_z_medium.jpg',
#                                   'shelved_url': 'https://images4-g.ravelrycache.com/uploads/elinor/561363442/447701457_f2ed2ec151_z_shelved.jpg',
#                                   'small2_url': 'https://images4-f.ravelrycache.com/uploads/elinor/561363442/447701457_f2ed2ec151_z_small2.jpg',
#                                   'small_url': 'https://images4-g.ravelrycache.com/uploads/elinor/561363442/447701457_f2ed2ec151_z_small.jpg',
#                                   'sort_order': 1,
#                                   'square_url': 'https://images4-f.ravelrycache.com/uploads/elinor/561363442/447701457_f2ed2ec151_z_square.jpg',
#                                   'thumbnail_url': 'https://images4-g.ravelrycache.com/uploads/elinor/561363442/447701457_f2ed2ec151_z_thumbnail.jpg',
#                                   'x_offset': -36,
#                                   'y_offset': 6},
#                                  {'caption': None,
#                                   'caption_html': None,
#                                   'copyright_holder': None,
#                                   'flickr_url': 'http://www.flickr.com/photos/48527722@N00/447697008',
#                                   'id': 8905958,
#                                   'medium2_url': 'https://images4-g.ravelrycache.com/flickr/4/4/7/447697008/447697008.jpg',
#                                   'medium_url': 'https://images4-g.ravelrycache.com/flickr/4/4/7/447697008/447697008.jpg',
#                                   'shelved_url': None,
#                                   'small2_url': 'https://images4-g.ravelrycache.com/flickr/4/4/7/447697008/447697008_n.jpg',
#                                   'small_url': 'https://images4-g.ravelrycache.com/flickr/4/4/7/447697008/447697008_m.jpg',
#                                   'sort_order': 2,
#                                   'square_url': 'https://images4-g.ravelrycache.com/flickr/4/4/7/447697008/447697008_s.jpg',
#                                   'thumbnail_url': 'https://images4-g.ravelrycache.com/flickr/4/4/7/447697008/447697008_t.jpg',
#                                   'x_offset': 0,
#                                   'y_offset': 0}],
#                       'price': None,
#                       'printings': [{'pattern_source': {'amazon_rating': None,
#                                                         'amazon_url': None,
#                                                         'author': '',
#                                                         'id': 231,
#                                                         'list_price': None,
#                                                         'name': 'Phildar No. '
#                                                                 '426, Layette, '
#                                                                 'Printemps-Été/Spring-Summer '
#                                                                 '2005',
#                                                         'out_of_print': False,
#                                                         'patterns_count': 7,
#                                                         'permalink': 'phildar-no-426-layette-printemps-ete-spring-summer-2005',
#                                                         'price': None,
#                                                         'shelf_image_path': 'http://images4.ravelry.com/uploads/MSCRoman/6338649/cover_shelved.jpg',
#                                                         'url': ''},
#                                      'primary_source': True}],
#                       'product_id': None,
#                       'projects_count': 1,
#                       'published': None,
#                       'queued_projects_count': 1,
#                       'rating_average': 0,
#                       'rating_count': None,
#                       'ravelry_download': False,
#                       'row_gauge': 29.0,
#                       'sizes_available': '3, 6, 12, 18, 24 mois',
#                       'updated_at': '2018/11/05 15:13:27 -0500',
#                       'url': '',
#                       'volumes_in_library': [],
#                       'yardage': 225,
#                       'yardage_description': '225 - 451 yards',
#                       'yardage_max': 451,
#                       'yarn_weight': {'crochet_gauge': '',
#                                       'id': 1,
#                                       'knit_gauge': '18',
#                                       'max_gauge': None,
#                                       'min_gauge': None,
#                                       'name': 'Aran',
#                                       'ply': '10',
#                                       'wpi': '8'},
#                       'yarn_weight_description': 'Aran (8 wpi)'}}}
# ['Argyle Cardigan', '08 - Débardeur #426-T4-370']

# %%
params = {'ids':'600 601'}
end_point = 'patterns.json' 
# response =requests.get('https://api.ravelry.com/color_families.json', auth=HTTPBasicAuth(basic_auth_username, basic_auth_password))
response =requests.get('https://api.ravelry.com/patterns.json', params=params,auth=HTTPBasicAuth(basic_auth_username, basic_auth_password))
# response =requests.get('https://api.ravelry.com/patterns/{id}.json', auth=HTTPBasicAuth(basic_auth_username, basic_auth_password))
# /pattern_sources/{id}.json
response.json()
# Out:
# {'patterns': {'600': {'comments_count': 1,
#    'created_at': '2007/04/05 19:23:43 -0400',
#    'currency': 'USD',
#    'difficulty_average': 3.888888888888889,
#    'difficulty_count': 27,
#    'downloadable': False,
#    'favorites_count': 230,
#    'free': False,
#    'gauge': 25.0,
#    'gauge_divisor': 4,
#    'gauge_pattern': 'Stockinette stitch',
#    'generally_available': '2007/04/05 19:23:43 -0400',
#    'id': 600,
#    'name': 'Argyle Cardigan',
#    'pdf_url': '',
#    'permalink': 'argyle-cardigan',
#    'price': None,
#    'projects_count': 79,
#    'published': None,
#    'queued_projects_count': 34,
#    'rating_average': 4.076923076923077,
#    'rating_count': 26,
#    'row_gauge': 34.0,
#    'updated_at': '2018/11/07 08:55:26 -0500',
#    'url': '',
#    'yardage': 548,
#    'yardage_max': 822,
#    'personal_attributes': {'favorited': False,
#     'bookmark_id': None,
#     'queued': False,
#     'in_library': False},
#    'sizes_available': '0-3 months (3-6 mo., 6-9 mo., 9-12 mo., 12-24 mo.)',
#    'product_id': None,
#    'currency_symbol': '$',
#    'ravelry_download': False,
#    'download_location': None,
#    'pdf_in_library': False,
#    'volumes_in_library': [],
#    'gauge_description': '25 stitches and 34 rows = 4 inches in Stockinette stitch',
#    'yarn_weight_description': 'Sport (12 wpi)',
#    'yardage_description': '548 - 822 yards',
#    'pattern_needle_sizes': [{'id': 3,
#      'us': '3 ',
#      'metric': 3.25,
#      'us_steel': '0',
#      'crochet': False,
#      'knitting': True,
#      'hook': 'D',
#      'name': 'US 3  - 3.25 mm',
#      'pretty_metric': '3.25'},
#     {'id': 20,
#      'us': '2½',
#      'metric': 3.0,
#      'us_steel': None,
#      'crochet': False,
#      'knitting': True,
#      'hook': None,
#      'name': 'US 2½ - 3.0 mm',
#      'pretty_metric': '3'}],
#    'notes_html': '\n<p>A cute baby cardigan with ribbed edging, button enclosure, and argyle detailing at the bottom of the sweater.<br /> <br /><br /> <br />Additional supplies: Small amounts of white and Indigo yarn, 6 or 7 buttons.</p>\n',
#    'notes': 'A cute baby cardigan with ribbed edging, button enclosure, and argyle detailing at the bottom of the sweater.<br />\r\n<br />\r\nAdditional supplies: Small amounts of white and Indigo yarn, 6 or 7 buttons.',
#    'packs': [{'id': 12632,
#      'primary_pack_id': None,
#      'project_id': None,
#      'skeins': None,
#      'stash_id': None,
#      'total_grams': None,
#      'total_meters': None,
#      'total_ounces': None,
#      'total_yards': None,
#      'yarn_id': 3217,
#      'yarn_name': 'Debbie Bliss Baby Cashmerino',
#      'yarn_weight': {'crochet_gauge': None,
#       'id': 10,
#       'knit_gauge': '24-26',
#       'max_gauge': None,
#       'min_gauge': None,
#       'name': 'Sport',
#       'ply': '5',
#       'wpi': '12'},
#      'colorway': None,
#      'shop_name': None,
#      'yarn': {'permalink': 'debbie-bliss-baby-cashmerino',
#       'id': 3217,
#       'name': 'Baby Cashmerino',
#       'yarn_company_name': 'Debbie Bliss',
#       'yarn_company_id': 2},
#      'quantity_description': None,
#      'personal_name': '',
#      'dye_lot': None,
#      'color_family_id': None,
#      'grams_per_skein': 50,
#      'yards_per_skein': 137.0,
#      'meters_per_skein': 125.3,
#      'ounces_per_skein': 1.76,
#      'prefer_metric_weight': True,
#      'prefer_metric_length': False,
#      'shop_id': None,
#      'thread_size': None}],
#    'printings': [{'primary_source': True,
#      'pattern_source': {'amazon_rating': None,
#       'amazon_url': 'https://www.amazon.com/Special-Knits-Gorgeous-Handknits-Toddlers/dp/157076302X?SubscriptionId=AKIAIVR5RCD3ZTXIG7RA&tag=ravelry-20&linkCode=xm2&camp=2025&creative=165953&creativeASIN=157076302X',
#       'author': 'Debbie Bliss',
#       'id': 295,
#       'list_price': '$26.95',
#       'name': 'Special Knits: 22 Gorgeous Handknits for Babies and Toddlers',
#       'out_of_print': False,
#       'patterns_count': 22,
#       'permalink': 'special-knits-22-gorgeous-handknits-for-babies-and-toddlers',
#       'price': None,
#       'shelf_image_path': 'http://images4.ravelry.com/uploads/nobody/94720/51p_2bejp5wll_shelved.jpg',
#       'url': ''}}],
#    'yarn_weight': {'crochet_gauge': None,
#     'id': 10,
#     'knit_gauge': '24-26',
#     'max_gauge': None,
#     'min_gauge': None,
#     'name': 'Sport',
#     'ply': '5',
#     'wpi': '12'},
#    'craft': {'id': 2, 'name': 'Knitting', 'permalink': 'knitting'},
#    'pattern_categories': [{'id': 304,
#      'name': 'Cardigan',
#      'permalink': 'cardigan',
#      'parent': {'id': 319,
#       'name': 'Sweater',
#       'permalink': 'sweater',
#       'parent': {'id': 302,
#        'name': 'Clothing',
#        'permalink': 'clothing',
#        'parent': {'id': 301,
#         'name': 'Categories',
#         'permalink': 'categories'}}}}],
#    'pattern_attributes': [{'id': 3, 'permalink': 'unisex'},
#     {'id': 4, 'permalink': 'baby'},
#     {'id': 7, 'permalink': 'toddler'},
#     {'id': 64, 'permalink': 'ribbed'},
#     {'id': 86, 'permalink': 'seamed'},
#     {'id': 117, 'permalink': 'long-sleeve'},
#     {'id': 181, 'permalink': 'stranded'},
#     {'id': 190, 'permalink': 'buttonholes'},
#     {'id': 265, 'permalink': 'chart'},
#     {'id': 267, 'permalink': 'written-pattern'},
#     {'id': 285, 'permalink': 'worked-flat'}],
#    'pattern_author': {'crochet_pattern_count': 22,
#     'favorites_count': 3193,
#     'id': 16,
#     'knitting_pattern_count': 2305,
#     'name': 'Debbie Bliss',
#     'patterns_count': 2327,
#     'permalink': 'debbie-bliss',
#     'notes': "Debbie Bliss has her own yarn line made up of beautiful classics in her signature palette. She is also the most published knitwear designer, with over 35 books, 20 booklets and her own magazine. She was also recently awarded with an MBE in the Queen's 2015 Birthday Honours List for her services to hand knitting and the craft industry.",
#     'notes_html': '\n<p>Debbie Bliss has her own yarn line made up of beautiful classics in her signature palette. She is also the most published knitwear designer, with over 35 books, 20 booklets and her own magazine. She was also recently awarded with an MBE in the Queen’s 2015 Birthday Honours List for her services to hand knitting and the craft industry.</p>\n',
#     'users': [{'fave_colors': '',
#       'fave_curse': '',
#       'first_name': 'Debbie',
#       'id': 755817,
#       'location': 'London, Greater London, United Kingdom',
#       'username': 'DebbieBliss',
#       'tiny_photo_url': 'https://avatars-d.ravelrycache.com/DebbieBliss/376375163/debbie_web_headshot__tiny.jpg',
#       'small_photo_url': 'https://avatars-d.ravelrycache.com/DebbieBliss/376375163/debbie_web_headshot__small.jpg',
#       'photo_url': 'https://avatars-d.ravelrycache.com/DebbieBliss/376375163/debbie_web_headshot__large.jpg',
#       'large_photo_url': 'https://avatars-d.ravelrycache.com/DebbieBliss/376375163/debbie_web_headshot__xlarge.jpg',
#       'about_me': '',
#       'about_me_html': None,
#       'pattern_author': {'favorites_count': 3193,
#        'id': 16,
#        'name': 'Debbie Bliss',
#        'patterns_count': 2327,
#        'permalink': 'debbie-bliss'},
#       'user_sites': [{'id': 263451,
#         'username': 'debbieblissonline',
#         'url': 'http://www.facebook.com/debbieblissonline',
#         'social_site': {'id': 8,
#          'name': 'Facebook',
#          'favicon_url': 'http:///images/assets/external/supertinyicons/facebook.svg',
#          'active': True}},
#        {'id': 263452,
#         'username': 'debbieblissnews',
#         'url': 'http://twitter.com/debbieblissnews',
#         'social_site': {'id': 9,
#          'name': 'Twitter',
#          'favicon_url': 'http:///images/assets/external/supertinyicons/twitter.svg',
#          'active': True}},
#        {'id': 263453,
#         'username': 'debbieblissknits',
#         'url': 'http://instagram.com/debbieblissknits',
#         'social_site': {'id': 28,
#          'name': 'Instagram',
#          'favicon_url': 'http:///images/assets/external/supertinyicons/instagram.svg',
#          'active': True}}]}]},
#    'photos': [{'id': 657899,
#      'sort_order': 1,
#      'x_offset': -63,
#      'y_offset': 0,
#      'square_url': 'https://images4-f.ravelrycache.com/uploads/annypurls/564079538/119324017_f15d25e534_z_square.jpg',
#      'medium_url': 'https://images4-f.ravelrycache.com/uploads/annypurls/564079538/119324017_f15d25e534_z_medium.jpg',
#      'thumbnail_url': 'https://images4-g.ravelrycache.com/uploads/annypurls/564079538/119324017_f15d25e534_z_thumbnail.jpg',
#      'small_url': 'https://images4-f.ravelrycache.com/uploads/annypurls/564079538/119324017_f15d25e534_z_small.jpg',
#      'flickr_url': 'http://www.flickr.com/photos/57409166@N00/119324017',
#      'shelved_url': 'https://images4-f.ravelrycache.com/uploads/annypurls/564079538/119324017_f15d25e534_z_shelved.jpg',
#      'medium2_url': 'https://images4-f.ravelrycache.com/uploads/annypurls/564079538/119324017_f15d25e534_z_medium2.jpg',
#      'small2_url': 'https://images4-f.ravelrycache.com/uploads/annypurls/564079538/119324017_f15d25e534_z_small2.jpg',
#      'caption': None,
#      'caption_html': None,
#      'copyright_holder': None},
#     {'id': 17328748,
#      'sort_order': 2,
#      'x_offset': -31,
#      'y_offset': -12,
#      'square_url': 'https://images4-g.ravelrycache.com/flickr/2/9/3/2936298096/2936298096_s.jpg',
#      'medium_url': 'https://images4-g.ravelrycache.com/flickr/2/9/3/2936298096/2936298096.jpg',
#      'thumbnail_url': 'https://images4-g.ravelrycache.com/flickr/2/9/3/2936298096/2936298096_t.jpg',
#      'small_url': 'https://images4-g.ravelrycache.com/flickr/2/9/3/2936298096/2936298096_m.jpg',
#      'flickr_url': 'http://www.flickr.com/photos/26033532@N02/2936298096',
#      'shelved_url': None,
#      'medium2_url': 'https://images4-g.ravelrycache.com/flickr/2/9/3/2936298096/2936298096.jpg',
#      'small2_url': 'https://images4-g.ravelrycache.com/flickr/2/9/3/2936298096/2936298096_n.jpg',
#      'caption': None,
#      'caption_html': None,
#      'copyright_holder': None},
#     {'id': 24370,
#      'sort_order': 3,
#      'x_offset': -68,
#      'y_offset': 1,
#      'square_url': 'https://images4-g.ravelrycache.com/uploads/elinor/561367483/447698728_ebe3cf7fdf_z_square.jpg',
#      'medium_url': 'https://images4-g.ravelrycache.com/uploads/elinor/561367483/447698728_ebe3cf7fdf_z_medium.jpg',
#      'thumbnail_url': 'https://images4-g.ravelrycache.com/uploads/elinor/561367483/447698728_ebe3cf7fdf_z_thumbnail.jpg',
#      'small_url': 'https://images4-g.ravelrycache.com/uploads/elinor/561367483/447698728_ebe3cf7fdf_z_small.jpg',
#      'flickr_url': 'http://www.flickr.com/photos/48527722@N00/447698728',
#      'shelved_url': 'https://images4-g.ravelrycache.com/uploads/elinor/561367483/447698728_ebe3cf7fdf_z_shelved.jpg',
#      'medium2_url': 'https://images4-f.ravelrycache.com/uploads/elinor/561367483/447698728_ebe3cf7fdf_z_medium2.jpg',
#      'small2_url': 'https://images4-g.ravelrycache.com/uploads/elinor/561367483/447698728_ebe3cf7fdf_z_small2.jpg',
#      'caption': None,
#      'caption_html': None,
#      'copyright_holder': None}],
#    'pattern_type': {'clothing': True,
#     'id': 5,
#     'name': 'Baby',
#     'permalink': 'baby'}},
#   '601': {'comments_count': 0,
#    'created_at': '2007/04/05 19:32:19 -0400',
#    'currency': 'USD',
#    'difficulty_average': 0,
#    'difficulty_count': None,
#    'downloadable': False,
#    'favorites_count': 8,
#    'free': False,
#    'gauge': 22.0,
#    'gauge_divisor': 4,
#    'gauge_pattern': 'stocking stitch (jersey) on 5mm needles',
#    'generally_available': '2005/03/01 00:00:00 -0500',
#    'id': 601,
#    'name': '08 - Débardeur #426-T4-370',
#    'pdf_url': '',
#    'permalink': '08---debardeur-426-t4-370',
#    'price': None,
#    'projects_count': 1,
#    'published': None,
#    'queued_projects_count': 1,
#    'rating_average': 0,
#    'rating_count': None,
#    'row_gauge': 29.0,
#    'updated_at': '2018/11/05 15:13:27 -0500',
#    'url': '',
#    'yardage': 225,
#    'yardage_max': 451,
#    'personal_attributes': {'favorited': False,
#     'bookmark_id': None,
#     'queued': False,
#     'in_library': False},
#    'sizes_available': '3, 6, 12, 18, 24 mois',
#    'product_id': None,
#    'currency_symbol': '$',
#    'ravelry_download': False,
#    'download_location': None,
#    'pdf_in_library': False,
#    'volumes_in_library': [],
#    'gauge_description': '22 stitches and 29 rows = 4 inches in stocking stitch (jersey) on 5mm needles',
#    'yarn_weight_description': 'Aran (8 wpi)',
#    'yardage_description': '225 - 451 yards',
#    'pattern_needle_sizes': [{'id': 7,
#      'us': '7 ',
#      'metric': 4.5,
#      'us_steel': None,
#      'crochet': False,
#      'knitting': True,
#      'hook': None,
#      'name': 'US 7  - 4.5 mm',
#      'pretty_metric': '4.5'},
#     {'id': 8,
#      'us': '8 ',
#      'metric': 5.0,
#      'us_steel': None,
#      'crochet': False,
#      'knitting': True,
#      'hook': 'H',
#      'name': 'US 8  - 5.0 mm',
#      'pretty_metric': '5'}],
#    'notes_html': '\n<p>Sizes: 3 (6, 12, 18, 24) mois <br />Yarn Needed: 2 (2, 3, 3, 4) balls <br />Also Needed: 1 bouton 14mm</p>\n',
#    'notes': 'Sizes: 3 (6, 12, 18, 24) mois\r\nYarn Needed: 2 (2, 3, 3, 4) balls\r\nAlso Needed: 1 bouton 14mm',
#    'packs': [{'id': 17447053,
#      'primary_pack_id': None,
#      'project_id': None,
#      'skeins': None,
#      'stash_id': None,
#      'total_grams': None,
#      'total_meters': None,
#      'total_ounces': None,
#      'total_yards': None,
#      'yarn_id': 3508,
#      'yarn_name': 'Phildar Rivage',
#      'yarn_weight': {'crochet_gauge': '',
#       'id': 1,
#       'knit_gauge': '18',
#       'max_gauge': None,
#       'min_gauge': None,
#       'name': 'Aran',
#       'ply': '10',
#       'wpi': '8'},
#      'colorway': None,
#      'shop_name': None,
#      'yarn': {'permalink': 'phildar-rivage',
#       'id': 3508,
#       'name': 'Rivage',
#       'yarn_company_name': 'Phildar',
#       'yarn_company_id': 221},
#      'quantity_description': None,
#      'personal_name': None,
#      'dye_lot': None,
#      'color_family_id': None,
#      'grams_per_skein': None,
#      'yards_per_skein': None,
#      'meters_per_skein': None,
#      'ounces_per_skein': None,
#      'prefer_metric_weight': True,
#      'prefer_metric_length': False,
#      'shop_id': None,
#      'thread_size': None}],
#    'printings': [{'primary_source': True,
#      'pattern_source': {'amazon_rating': None,
#       'amazon_url': None,
#       'author': '',
#       'id': 231,
#       'list_price': None,
#       'name': 'Phildar No. 426, Layette, Printemps-Été/Spring-Summer 2005',
#       'out_of_print': False,
#       'patterns_count': 7,
#       'permalink': 'phildar-no-426-layette-printemps-ete-spring-summer-2005',
#       'price': None,
#       'shelf_image_path': 'http://images4.ravelry.com/uploads/MSCRoman/6338649/cover_shelved.jpg',
#       'url': ''}}],
#    'yarn_weight': {'crochet_gauge': '',
#     'id': 1,
#     'knit_gauge': '18',
#     'max_gauge': None,
#     'min_gauge': None,
#     'name': 'Aran',
#     'ply': '10',
#     'wpi': '8'},
#    'craft': {'id': 2, 'name': 'Knitting', 'permalink': 'knitting'},
#    'pattern_categories': [{'id': 308,
#      'name': 'Sleeveless Top',
#      'permalink': 'sleeveless-top',
#      'parent': {'id': 912,
#       'name': 'Tops',
#       'permalink': 'tops',
#       'parent': {'id': 302,
#        'name': 'Clothing',
#        'permalink': 'clothing',
#        'parent': {'id': 301,
#         'name': 'Categories',
#         'permalink': 'categories'}}}}],
#    'pattern_attributes': [{'id': 2, 'permalink': 'female'},
#     {'id': 4, 'permalink': 'baby'},
#     {'id': 7, 'permalink': 'toddler'},
#     {'id': 61, 'permalink': 'eyelets'},
#     {'id': 70, 'permalink': 'textured'},
#     {'id': 97, 'permalink': 'crew-neck'},
#     {'id': 121, 'permalink': 'sleeveless'},
#     {'id': 136, 'permalink': 'buttoned'},
#     {'id': 139, 'permalink': 'backfastening'},
#     {'id': 190, 'permalink': 'buttonholes'},
#     {'id': 62, 'permalink': 'lace'},
#     {'id': 86, 'permalink': 'seamed'},
#     {'id': 267, 'permalink': 'written-pattern'},
#     {'id': 285, 'permalink': 'worked-flat'}],
#    'pattern_author': {'crochet_pattern_count': 237,
#     'favorites_count': 1273,
#     'id': 202,
#     'knitting_pattern_count': 3550,
#     'name': 'Phildar Design Team',
#     'patterns_count': 3787,
#     'permalink': 'phildar-design-team',
#     'notes': '',
#     'notes_html': None,
#     'users': []},
#    'photos': [{'id': 24371,
#      'sort_order': 1,
#      'x_offset': -36,
#      'y_offset': 6,
#      'square_url': 'https://images4-f.ravelrycache.com/uploads/elinor/561363442/447701457_f2ed2ec151_z_square.jpg',
#      'medium_url': 'https://images4-f.ravelrycache.com/uploads/elinor/561363442/447701457_f2ed2ec151_z_medium.jpg',
#      'thumbnail_url': 'https://images4-g.ravelrycache.com/uploads/elinor/561363442/447701457_f2ed2ec151_z_thumbnail.jpg',
#      'small_url': 'https://images4-g.ravelrycache.com/uploads/elinor/561363442/447701457_f2ed2ec151_z_small.jpg',
#      'flickr_url': 'http://www.flickr.com/photos/48527722@N00/447701457',
#      'shelved_url': 'https://images4-g.ravelrycache.com/uploads/elinor/561363442/447701457_f2ed2ec151_z_shelved.jpg',
#      'medium2_url': 'https://images4-f.ravelrycache.com/uploads/elinor/561363442/447701457_f2ed2ec151_z_medium2.jpg',
#      'small2_url': 'https://images4-f.ravelrycache.com/uploads/elinor/561363442/447701457_f2ed2ec151_z_small2.jpg',
#      'caption': None,
#      'caption_html': None,
#      'copyright_holder': None},
#     {'id': 8905958,
#      'sort_order': 2,
#      'x_offset': 0,
#      'y_offset': 0,
#      'square_url': 'https://images4-g.ravelrycache.com/flickr/4/4/7/447697008/447697008_s.jpg',
#      'medium_url': 'https://images4-g.ravelrycache.com/flickr/4/4/7/447697008/447697008.jpg',
#      'thumbnail_url': 'https://images4-g.ravelrycache.com/flickr/4/4/7/447697008/447697008_t.jpg',
#      'small_url': 'https://images4-g.ravelrycache.com/flickr/4/4/7/447697008/447697008_m.jpg',
#      'flickr_url': 'http://www.flickr.com/photos/48527722@N00/447697008',
#      'shelved_url': None,
#      'medium2_url': 'https://images4-g.ravelrycache.com/flickr/4/4/7/447697008/447697008.jpg',
#      'small2_url': 'https://images4-g.ravelrycache.com/flickr/4/4/7/447697008/447697008_n.jpg',
#      'caption': None,
#      'caption_html': None,
#      'copyright_holder': None}],
#    'pattern_type': {'clothing': True,
#     'id': 5,
#     'name': 'Baby',
#     'permalink': 'baby'}}}}

# %%
# Out:
# {'color_families': [{'color': None,
#    'id': 1,
#    'name': 'Yellow',
#    'permalink': 'Yellow',
#    'spectrum_order': 1},
#   {'color': None,
#    'id': 2,
#    'name': 'Yellow-orange',
#    'permalink': 'Yellow-orange',
#    'spectrum_order': 2},
#   {'color': None,
#    'id': 3,
#    'name': 'Orange',
#    'permalink': 'Orange',
#    'spectrum_order': 3},
#   {'color': None,
#    'id': 4,
#    'name': 'Red-orange',
#    'permalink': 'Red-orange',
#    'spectrum_order': 4},
#   {'color': None,
#    'id': 5,
#    'name': 'Red',
#    'permalink': 'Red',
#    'spectrum_order': 5},
#   {'color': None,
#    'id': 6,
#    'name': 'Red-purple',
#    'permalink': 'Red-purple',
#    'spectrum_order': 0},
#   {'color': None,
#    'id': 7,
#    'name': 'Purple',
#    'permalink': 'Purple',
#    'spectrum_order': 8},
#   {'color': None,
#    'id': 8,
#    'name': 'Blue-purple',
#    'permalink': 'Blue-purple',
#    'spectrum_order': 9},
#   {'color': None,
#    'id': 9,
#    'name': 'Blue',
#    'permalink': 'Blue',
#    'spectrum_order': 10},
#   {'color': None,
#    'id': 10,
#    'name': 'Blue-green',
#    'permalink': 'Blue-green',
#    'spectrum_order': 11},
#   {'color': None,
#    'id': 11,
#    'name': 'Green',
#    'permalink': 'Green',
#    'spectrum_order': 12},
#   {'color': None,
#    'id': 12,
#    'name': 'Yellow-green',
#    'permalink': 'Yellow-green',
#    'spectrum_order': 13},
#   {'color': None,
#    'id': 13,
#    'name': 'Black',
#    'permalink': 'Black',
#    'spectrum_order': 14},
#   {'color': None,
#    'id': 14,
#    'name': 'White',
#    'permalink': 'White',
#    'spectrum_order': 15},
#   {'color': None,
#    'id': 15,
#    'name': 'Gray',
#    'permalink': 'Gray',
#    'spectrum_order': 16},
#   {'color': None,
#    'id': 16,
#    'name': 'Brown',
#    'permalink': 'Brown',
#    'spectrum_order': 17},
#   {'color': None,
#    'id': 17,
#    'name': 'Pink',
#    'permalink': 'Pink',
#    'spectrum_order': 18},
#   {'color': None,
#    'id': 18,
#    'name': 'Natural/Undyed',
#    'permalink': 'Natural/Undyed',
#    'spectrum_order': 19},
#   {'color': None,
#    'id': 19,
#    'name': 'Multicolored',
#    'permalink': 'Multicolored',
#    'spectrum_order': 21},
#   {'color': None,
#    'id': 20,
#    'name': 'Rainbow\t',
#    'permalink': 'Rainbow',
#    'spectrum_order': 20}]}
